# %%
️ Supervised Learning

Definition:
Supervised Learning is a type of Machine Learning where the model is trained using labeled data. This means each input comes with a correct output (answer). The algorithm learns the relationship between inputs and outputs so it can predict answers for new, unseen data

️ Unsupervised Learning

Definition:
Unsupervised Learning is a type of Machine Learning where the data does not contain labels or correct answers. The algorithm tries to discover hidden patterns, structures, or clusters within the data on its own.

️ Reinforcement Learning

Definition:
Reinforcement Learning is a type of Machine Learning where an agent learns by interacting with an environment. It receives rewards for correct actions and penalties for wrong actions, and it improves its strategy over time to maximize total reward.


 Comparison Table with Real-World Examples


Learning Type	Data Type	Real-World Example	Why It Fits
Supervised Learning	Labeled data	Spam Email Detection	Emails are labeled as "Spam" or "Not Spam"
		House Price Prediction	Houses have known prices (target value)
Unsupervised Learning	Unlabeled data	Customer Segmentation	Customers grouped based on behavior without labels
		Market Basket Analysis	Finds product purchase patterns without predefined groups
Reinforcement Learning	Reward-based feedback	Game Playing AI	Learns moves by winning (reward) or losing (penalty)
		Self-Driving Cars	Learns driving decisions based on reward signals (safe driving)
